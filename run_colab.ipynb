# %% [markdown]
# ### Klonowanie repozytorium

# %%
# !git clone https://github.com/magmatti/agent-based-traffic-model.git
# %cd agent-based-traffic-model
# Out:
# Cloning into 'agent-based-traffic-model'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 151 (delta 68), reused 120 (delta 40), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 1.02 MiB | 45.39 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# /content/agent-based-traffic-model

# %% [markdown]
# ### Intalcja dependencji

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 40.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Uruchomienie main.py (glowna aplikacja konsolowa dla testow CUDA, OpenMP oraz sekwencyjnych)

# %%
# !python main.py
# Out:
# === Agent-based Traffic Simulation ===
# === Choose backend ===
# 1. sequential
# 2. openmp
# 3. cuda
# Enter number: 3
# Total simulation time [s] (default 300): 3000
# Time step dt [s] (default 0.1): 0.1
# Spawn rate [veh/s/direction] (default 0.5): 0.5
# Max vehicles in world (default 2000): 2000
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:697: NumbaPerformanceWarning: Grid size 4 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.12/dist-packages/numba_cuda/numba/cuda/dispatcher.py:697: NumbaPerformanceWarning: Grid size 4 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))

# %% [markdown]
# ### Uruchamianie wersji MPI

# %%
# !mpiexec --allow-run-as-root --oversubscribe -n 8 python run_mpi.py

# %% [markdown]
# Wyniki wszystkich testow zapisują się w katalogu results/
